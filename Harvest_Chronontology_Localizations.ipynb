# %% [markdown]
# ## Script for harvesting location data from iDAI.chronontology
#
# This simple script can be used to extract location assignments in Chronontology.
#
# An excerpt from the Chronontology konkordanz.csv is read in.
#
# The output is a list of all place names and IDs in iDAI.gazetteer that are primarily associated with the entered periods. This means that core areas are preferred over regions, and regions in turn over eponymous places.
#
# ---
# ### Skript zum Harvesten von Ortsdaten aus iDAI.chronontology
#
# Mithlife dieses einfachen Skripts lassen sich Ortszuweisungen in Chronontology extrahieren.
#
# Eingelesen wird ein Auszug der Chronontology Konkordanz.
#
# Ausgegeben wird eine Liste aller Ortsnamen und IDs im iDAI.gazetteer, die mit den eingegebenen Perioden primär assoziiert sind. Dies bedeutet, dass Kerngebeite gegenüber Regionen bevorzugt werden, und Regionen wiederrum über namensgebende Orte.

# %%
#Import modules

import pandas as pd
import requests
import time

# %%
#Read Konkordanz

#Choose CSV or Excel file
#df_konkordanz = pd.read_excel("konkordanz_20240527.xlsx", sheet_name="nur SPP")
df_konkordanz = pd.read_csv("konkordanz_nur_SPP_2026-07-10.csv", sep=",", encoding="utf-8")
print(df_konkordanz)
# Out:
#     chronontologyID      importID             name      type provenance
# 0      Ucu5OIeMk87K         A0362         Pleiocen       NaN        NaN
# 1      phdN6seQVvst         A0365       Quaternary       NaN        NaN
# 2      lfG3F2CVH6L5         A0366    \nPleistocene       NaN        NaN
# 3      uDnhWiMlThBu         A0371         Holocene       NaN        NaN
# 4      KSTwkyZWSSEo         A0532        Neolithic       NaN        NaN
# ..              ...           ...              ...       ...        ...
# 539    REJHg6TPQrTa  spp2143:0855        MIS XVIII  climatic    SPP2143
# 540    MD6HqNxOWLzt  spp2143:0856          MIS XIX  climatic    SPP2143
# 541    fMRQTlzqqRs7  spp2143:0857           MIS XX  climatic    SPP2143
# 542    0PKsrAUXEo5Y  spp2143:0858          MIS XXI  climatic    SPP2143
# 543    3u2kEy8c1CGG  spp2143:0859  8.2 ka BP Event  climatic    SPP2143
#
# [544 rows x 5 columns]

# %%
#List all ChronoIDs

chronoids = df_konkordanz["chronontologyID"]
chronoids = chronoids.tolist()

#print(chronoids)

# Uncomment the next line to limit the number of ChronoIDs for testing
#chronoids_test = chronoids[:10]

# %%
#Retrieve Title, Core Area or SpatiallPartOf from Chronontology API

url = "https://chronontology.dainst.org/data/period/"

#Function to retrieve the name of a period
def get_chrono_name(chrono_id):
    response = requests.get(f"{url}{chrono_id}")
    if response.status_code == 200:
        data = response.json()
        #print(data)
        title = data['resource']['names']
        #get the first value
        title = title.values()
        title = list(title)[0][0]
        #print(title)
        return title
    else:
        title = "ERROR"
        return title

#Function to retrieve the core area of a period
def get_chrono_core_area(chrono_id):
    response = requests.get(f"{url}{chrono_id}")
    if response.status_code == 200:
        data = response.json()
        #print(data['resource'])
        if 'hasCoreArea' in data['resource']:
            core_area = data['resource']['hasCoreArea'][0]
            return core_area
        else:
            core_area = "no_core_area"
            return core_area
    else:
        core_area = "ERROR"
        return core_area

#Function to retrieve the region of a period
def get_chrono_region(chrono_id):
    response = requests.get(f"{url}{chrono_id}")
    if response.status_code == 200:
        data = response.json()
        #print(data['resource'])
        if 'spatiallyPartOfRegion' in data['resource']:
            region = data['resource']['spatiallyPartOfRegion'][0]
            return region
        else:
            region = "no_region"
            return region
    else:
        region = "ERROR"
        return region

#Function to retrieve the place after a period is named
def get_chrono_named_after(chrono_id):
    response = requests.get(f"{url}{chrono_id}")
    if response.status_code == 200:
        data = response.json()
        #print(data['resource'])
        if 'isNamedAfter' in data['resource']:
            named_after = data['resource']['isNamedAfter'][0]
            return named_after
        else:
            named_after = "no_named_after"
            return named_after
    else:
        named_after = "ERROR"
        return named_after

# %%
#Function to retrieve the name of a place in the Gazetteer
def get_gaz_title(gaz_id):
    gaz_id = gaz_id.split("/")[-1]
    url = f"https://gazetteer.dainst.org/doc/{gaz_id}.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if 'prefName' in data:
            title = data['prefName']['title']
            return title
        else:
            title = "ERROR_no_title!!!"
            return title

# %%
#Main Loop

#uncomment to test the loop with three ids
#chronoids = ['oUj62ZmY8g8U','bPXYskijLKfh','iHHsmCseJynu']

processed_chrono_ids = []
result = []
names = []
gaz_titles = []
x = 0

for chrono_id in chronoids:
    x += 1
    print(f"processing {chrono_id}, nr. {x} of {len(chronoids)}")
    processed_chrono_ids.append(chrono_id)
    name = get_chrono_name(chrono_id)
    names.append(name)
    core_area = get_chrono_core_area(chrono_id)
    region = get_chrono_region(chrono_id)
    named_after = get_chrono_named_after(chrono_id)
    if core_area != "no_core_area":
        gaz_title = get_gaz_title(core_area)
        gaz_titles.append(gaz_title)
        result.append(core_area)
    elif region != "no_region":
        gaz_title = get_gaz_title(region)
        gaz_titles.append(gaz_title)
        result.append(region)
    elif named_after != "no_named_after":
        gaz_title = get_gaz_title(named_after)
        gaz_titles.append(gaz_title)
        result.append(named_after)
    else:
        result.append("no_localization")
        gaz_titles.append("no_gaz_title")
    time.sleep(1)  # Sleep for 1 second to avoid overloading the API

# Create a DataFrame with the results
df_results = pd.DataFrame({
    'ChronoID': processed_chrono_ids,
    'PeriodName': names,
    'Localization': gaz_titles,
    'GazetteerID': result
})

print(df_results)
# Out:
# processing Ucu5OIeMk87K, nr. 1 of 544
# processing phdN6seQVvst, nr. 2 of 544
# processing lfG3F2CVH6L5, nr. 3 of 544
# processing uDnhWiMlThBu, nr. 4 of 544
# processing KSTwkyZWSSEo, nr. 5 of 544
# processing Pz9mflW8csGk, nr. 6 of 544
# processing vqP6C9DXZaM0, nr. 7 of 544
# processing iSj6SwX4NZbO, nr. 8 of 544
# processing QHzwmkJSowXm, nr. 9 of 544
# processing 1V7hXAceoGYF, nr. 10 of 544
# processing 3Fc39Jz0btde, nr. 11 of 544
# processing NZmuzJp1AFw6, nr. 12 of 544
# processing obrzU5TaqGbk, nr. 13 of 544
# processing sDgDdjwkV8R6, nr. 14 of 544
# processing iFSXg6L89xVF, nr. 15 of 544
# processing dd3ZBu95ym8I, nr. 16 of 544
# processing 7Tij3iA5o0oA, nr. 17 of 544
# processing Ag6gJByUlSg5, nr. 18 of 544
# processing 2exnuQecx5iY, nr. 19 of 544
# processing kICzVpoTKUGa, nr. 20 of 544
# processing XKGmzQ1kMTtc, nr. 21 of 544
# processing RBaEkQEX71vR, nr. 509 of 544
# processing Pvrx1dsBcHD0, nr. 510 of 544
# processing MxCFxb6kb5BH, nr. 511 of 544
# processing som0Q8E8RCRE, nr. 512 of 544
# processing eWh9DTnz7NNg, nr. 513 of 544
# processing MeLfGTto9iUQ, nr. 514 of 544
# processing 42jcgP1T8Fbi, nr. 515 of 544
# processing Ha8ruwZDrG8I, nr. 516 of 544
# processing Cfpi4886mymX, nr. 517 of 544
# processing PJ03WfBi5ZEl, nr. 518 of 544
# processing i1wvxPneD7GZ, nr. 519 of 544
# processing fbYvtbjU8J4k, nr. 520 of 544
# processing XzxST4c1GO6y, nr. 521 of 544
# processing PfOsCaT1JJYK, nr. 522 of 544
# processing eOaxgBoLKSZY, nr. 523 of 544
# processing yCEvJZKQEpoo, nr. 524 of 544
# processing d10CPOHAzNsd, nr. 525 of 544
# processing 6UzdTfGNOuYq, nr. 526 of 544
# processing SrZ3722kIhk2, nr. 527 of 544
# processing tzhYugGZr53r, nr. 528 of 544
# processing 7hgqMzzwmrFJ, nr. 529 of 544
# processing zJoKsaNZg17l, nr. 530 of 544
# processing 1JgRfdbYqBLz, nr. 531 of 544
# processing a33sTYeSKCdk, nr. 532 of 544
# processing hUKYDVwPeDTW, nr. 533 of 544
# processing DXmtQJ4BY4tk, nr. 534 of 544
# processing Rvt6K8cHmkwR, nr. 535 of 544
# processing 5oUlBM1u9Q14, nr. 536 of 544
# processing oITciNSH8lDV, nr. 537 of 544
# processing DR7JnsdELksv, nr. 538 of 544
# processing fMjxJsMOxdNZ, nr. 539 of 544
# processing REJHg6TPQrTa, nr. 540 of 544
# processing MD6HqNxOWLzt, nr. 541 of 544
# processing fMRQTlzqqRs7, nr. 542 of 544
# processing 0PKsrAUXEo5Y, nr. 543 of 544
# processing 3u2kEy8c1CGG, nr. 544 of 544
#           ChonoID       PeriodName Localization  \
# 0    Ucu5OIeMk87K          Pliozän         Welt
# 1    phdN6seQVvst          Quartär         Welt
# 2    lfG3F2CVH6L5       Pleistozän         Welt
# 3    uDnhWiMlThBu          Holozän         Welt
# 4    KSTwkyZWSSEo      Neolithikum   Nordafrika
# ..            ...              ...          ...
# 539  REJHg6TPQrTa        MIS XVIII         Welt
# 540  MD6HqNxOWLzt          MIS XIX         Welt
# 541  fMRQTlzqqRs7           MIS XX         Welt
# 542  0PKsrAUXEo5Y          MIS XXI         Welt
# 543  3u2kEy8c1CGG  8.2 ka BP Event       Africa
#
#                                     GazetteerID
# 0    https://gazetteer.dainst.org/place/2042600
# 1    https://gazetteer.dainst.org/place/2042600
# 2    https://gazetteer.dainst.org/place/2042600
# 3    https://gazetteer.dainst.org/place/2042600
# 4    https://gazetteer.dainst.org/place/2042602
# ..                                          ...
# 539   http://gazetteer.dainst.org/place/2042600
# 540   http://gazetteer.dainst.org/place/2042600
# 541   http://gazetteer.dainst.org/place/2042600
# 542   http://gazetteer.dainst.org/place/2042600
# 543   http://gazetteer.dainst.org/place/2042601
#
# [544 rows x 4 columns]

# %%
#export to Excel
df_results.to_excel("chronontology_gazetteer_mapping.xlsx", index=False)

# %% [markdown]
# To obtain only unique place names, the following code can be applied to the previously exported table:
#
# ---
#
# Um nur einzigartige Ortsbezeichnungen zu erhalten, kann der folgende Code auf die zuvor exportierte Tabelle angewendet werden:

# %%
#Get unique Gazetteer IDs with place names
df_gazetteer_mapping = pd.read_excel("chronontology_gazetteer_mapping.xlsx", usecols=["GazetteerID"])
unique_gazetteer_ids = df_gazetteer_mapping['GazetteerID'].unique()

placenames = []

for gaz_id in unique_gazetteer_ids:
    gaz_id = gaz_id.split("/")[-1]
    url = f"https://gazetteer.dainst.org/doc/{gaz_id}.json"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        if 'prefName' in data:
            title = data['prefName']['title']
            placenames.append((title))
            print(f"{gaz_id}: {title}")
        else:
            print(f"{gaz_id}: ERROR_no_title!!!")
            title = "ERROR_no_title!!!"
            placenames.append((title))
    else:
        print(f"{gaz_id}: ERROR fetching data")
        title = "ERROR fetching data"
        placenames.append((title))

# Create a DataFrame with the unique Gazetteer IDs and their place names
df_placenames = pd.DataFrame({
    'GazetteerID': unique_gazetteer_ids,
    'PlaceName': placenames
})

# Export the DataFrame to an Excel file
df_placenames.to_excel("unique_gazetteer_placenames.xlsx", index=False)
# Out:
# 2042600: Welt
# 2042602: Nordafrika
# 2042894: Nile
# 2042608: Nubien
# 2042600: Welt
# 2042611: Sahara
# 2042736: Wadi Howar (Region)
# 2770924: Ténéré
# 2766891: Vallée du Tîlemsi
# 2338507: Laqiya Region
# 2295325: al-Ǧilfu l-kabīr
# 2295326: Baḩr ar Rimāl al ‘Az̧īm
# 2338497: Abu Ballas region
# 2277657: ad-Dachla Oase
# 2345237: Djara
# 2338498: Abu Muhariq Plateau
# 2767573: Tigray
# 2348442: Eritrea
# 2767571: Al Wilāyah ash Sharqīyah
# 2290548: Jemen
# 2281810: Äthiopien
# 1006805: Tschadbecken
# 2042707: Sudan
# 2042601: Africa
# 2128989: Tschad
# 2293918: Brandberg
# 2293917: Namibia
# 2768913: Firgi Region
# 2768396: Wadi Abu Dom
# 2295200: Gala Abu Ahmed
# 2042725: Nubien
# 2353208: Nigeria
# 2345286: Abu Tabari
# 2338500: Nabta-Kiseiba
# 2768126: Vereinigte Arabische Republik
# 2379505: Aegyptus Superior
# 2751193: Fayyum Oasis
# 2751159: El Badari
# 2771779: Libyan Desert
# 2042786: Ägypten
# 2042878: Merimde-Benisalâme
# 2751406: El-Omari
# 2297343: Wilāyat an Nīl al Abyaḑ
# 2297394: Al Gash
# 2379056: Kerma Kingdom
# 2042921: Theben
# 1008083: Imbonga-Keramikstilgruppe
# 2773966: Bonkake-Keramikstilgruppe
# 2773967: Ingende-Keramikstilgruppe
# 1008084: Inganda-Keramikstilgruppe
# 2773968: Lokondola-Keramikstilgruppe
# 2773969: Yete-Keramikstilgruppe
# 2773970: Monkoto-Keramikstilgruppe
# 2773936: Bokele-Keramikstilgruppe
# 1008101: Lusako-Keramikstilgruppe
# 2768436: Keramikstilgruppe Bokuma/Lingonda
# 1008098: Longa-Keramikstilgruppe
# 2768440: Bondongo-Keramikstilgruppe
# 2773971: Mbandaka-Keramikstilgruppe
# 2773972: Nkile-Keramikstilgruppe
# 2773974: Botendo-Keramikstilgruppe
# 1008058: Bekongo-Keramikstilgruppe
# 2773937: Wafanya-Keramikstilgruppe
# 2773938: Wema-Keramikstilgruppe
# 2773939: Bosanga-Keramikstilgruppe
# 2773940: Bolondo-Keramikstilgruppe
# 2768441: Bokone-Keramikstilgruppe
# 2773975: Bolombi-Keramikstilgruppe
# 2773976: Ilemba-Bokonda-Keramikstilgruppe
# 2773941: Inkaka-Keramikstilgruppe
# 2773942: Liyolongo-Keramikstilgruppe
# 2773943: Yopoko-Keramikstilgruppe
# 2773944: Lokonge-Keramikstilgruppe
# 2773945: Likuku-Keramikstilgruppe
# 2773946: Malelembe-Keramikstilgruppe
# 2773973: Besongo-Keramikstilgruppe
# 2773947: Lisala-Keramikstilgruppe
# 2773948: Nkomba-Keramikstilgruppe
# 1008108: Mpokioko-Keramikstilgruppe
# 2773930: Verbreitungsgebiet der West-Keramiktradition
# 2774018: Ikenge-Keramikstilgruppe
# 2773934: Verbreitungsgebiet der Nord-Keramiktradition
# 2773929: Verbreitungsgebiet der Luilaka-Keramiktradition
# 2773931: Tshuapa-Keramiktradition
# 2773932: Verbreitungsgebiet der Busira-Keramiktradition
# 2773933: Verbreitungsgebiet der Maringa-Keramiktradition
# 2773928: Verbreitungsgebiet der Äquator-Co-Keramiktradition
# 2778862: Batalimo-Maluba-Keramikstilgruppe
# 2778860: Ngbanja-Keramikstilgruppe
# 2778863: Dongo-Keramikstilgruppe
# 2778864: Mokelo-Keramikstilgruppe
# 2778865: Bobulu-Keramikstilgruppe
# 2778866: Bokwango-Keramikstilgruppe
# 2778867: Motenge-Boma-Keramikstilgruppe
# 2778868: Kpetene-Keramikstilgruppe
# 2778869: Dama-Keramikstilgruppe
# 2778870: Mbati-Ngombe-Keramikstilgruppe
# 2778871: Bangui-Keramikstilgruppe
# 2778879: Pikunda-Munda-Keramikstilgruppe
# 2778872: Bokonongo-Keramikstilgruppe
# 2778873: Ngombe-Keramikstilgruppe
# 2778856: Matoto-Keramikstilgruppe
# 2778857: Ebambe-Keramikstilgruppe
# 2778858: Epena-Keramikstilgruppe
# 2778859: Mobaka-Keramikstilgruppe
# 2778861: Mandombe-Keramikstilgruppe
# 2778874: Konda-Keramikstilgruppe
# 2778875: Ouesso-Keramikstilgruppe
# 2778876: Pandama-Keramikstilgruppe
# 2778877: Mbenja-Keramikstilgruppe
# 2778878: Bobusa-Keramikstilgruppe
# 2778855: Ngoko-Keramiktradition
# 2293929: Ennedi (région)
# 2767994: Gajiganna B
# 2788394: Bama Deltaic Complex
# 2788395: Houlouf Chiefdom
# 1005700: Connecting Foodways study area
# 1008055: Akonetye North-Keramikstilgruppe
# 1008056: Akonetye South-Keramikstilgruppe
# 1008057: Angondjé-Keramikstilgruppe
# 1008059: Bidjouka-Keramikstilgruppe
# 1008060: Boko-Songho-Keramikstilgruppe
# 1008062: Bolaopi-Keramikstilgruppe
# 1008063: Buela-Keramikstilgruppe
# 1008064: Bwambé/Mpoengu-Keramikstilgruppe
# 1008065: Campo-Keramikstilgruppe
# 1008066: Carboneras-Keramikstilgruppe
# 1008067: Carinated Broadly Grooved-Keramikstilgruppe
# 1008068: Ceramic Later Stone Age 1-Keramikstilgruppe
# 1008069: Ceramic Later Stone Age 2-Keramikstilgruppe
# 1008070: Classical Kisalian-Keramikstilgruppe
# 1008071: Dibamba A-Keramikstilgruppe
# 1008072: Dibamba B-Keramikstilgruppe
# 1008073: Dibamba C-Keramikstilgruppe
# 1008074: Dibamba D-Keramikstilgruppe
# 1008075: Dibamba E-Keramikstilgruppe
# 1008076: Dimba/Mbafu/Group II-Keramikstilgruppe
# 1008077: Early Kisalian-Keramikstilgruppe
# 1008078: Early Pottery Phase-Keramikstilgruppe
# 1008079: Gombe-Keramikstilgruppe
# 1008080: Group X-Keramikstilgruppe
# 1008081: Herringbone-Keramikstilgruppe
# 1008082: Ilambi-Keramikstilgruppe
# 1008085: Iron Age I-Keramikstilgruppe
# 1008086: Kabambian A-Keramikstilgruppe
# 1008087: Kabambian B-Keramikstilgruppe
# 1008088: Kamilambian-Keramikstilgruppe
# 1008089: Kay Ladio-Keramikstilgruppe
# 1008090: Kindangakanzi-Keramikstilgruppe
# 1008091: Kindoki-Keramikstilgruppe
# 1008092: Kitala-Keramikstilgruppe
# 1008093: Kongo A/Group IV-Keramikstilgruppe
# 1008094: Kongo B/Group V-Keramikstilgruppe
# 1008095: Kongo C/Group III-Keramikstilgruppe
# 1008096: Kongo D-Keramikstilgruppe
# 1008099: Lope-Keramikstilgruppe
# 1008100: Luba-Keramikstilgruppe
# 1008102: Malongo/Bissiang-Keramikstilgruppe
# 1008103: Mbafu/Group II-Keramikstilgruppe
# 1008104: Middle Pottery Phase-Keramikstilgruppe
# 1008105: Mindouli-Keramikstilgruppe
# 1008106: Misenga/Mbafu/Group II-Keramikstilgruppe
# 1008107: Moubiri-Keramikstilgruppe
# 1008166: Muanda-Keramikstilgruppe
# 1008109: Nandá/Group II-Keramikstilgruppe
# 1008165: Ndindan-Keramikstilgruppe
# 1008110: Ngovo-Keramikstilgruppe
# 1008111: Obobogo-Keramikstilgruppe
# 1008112: Okala/Epona/Yindo-Keramikstilgruppe
# 1008113: Okanda-Keramikstilgruppe
# 1008114: Otoumbi-Keramikstilgruppe
# 1008115: Oveng-Keramikstilgruppe
# 1008116: Spaced Curvilinear-Keramikstilgruppe
# 1008117: Stone to Metal Age 1-Keramikstilgruppe
# 1008118: Stone to Metal Age 2-Keramikstilgruppe
# 1008120: Woven II-Keramikstilgruppe
# 1008119: Woven I-Keramikstilgruppe
# 1008121: Yaekela-Keramikstilgruppe
# 2042601: Africa

# %% [markdown]
# Developed by Lukas Lammers in the FAIR.rdm project, part of the DFG-funded SPP 2143 “Entangled Africa.”
#
# With support from GitHub Copilot (AI assistant) for code development and optimization.
#
# Version 1.1, July 30, 2025
#
# ---
#
# Entwickelt von Lukas Lammers im Projekt FAIR.rdm, teil des DFG-geförderten SPP 2143 "Entangled Africa".
#
# Mit Unterstützung von GitHub Copilot (KI-Assistent) bei der Code-Entwicklung und -Optimierung.
#
# Version 1.1, 30.07.2025
